# %% [markdown]
# # Análise de dados sobre Eleitorado Brasileiro

# %%
import pandas as pd

# %%
df = pd.read_csv('eleitorado_municipio_2018.csv', sep=';', encoding='latin1')

# %%
df.head().T
# Out:
#                                           0             1          2       3  \
# NR_ANO_ELEICAO                         2018          2018       2018    2018
# CD_PAIS                                   1             1          1       1
# NM_PAIS                              Brasil        Brasil     Brasil  Brasil
# SG_REGIAO                                 N             N          N       N
# NM_REGIAO                             Norte         Norte      Norte   Norte
# SG_UF                                    AC            AC         AC      AC
# NM_UF                                  Acre          Acre       Acre    Acre
# CD_MUNICIPIO                           1120          1570       1058    1007
# NM_MUNICIPIO                     ACRELÂNDIA  ASSIS BRASIL  BRASILÉIA  BUJARI
# QTD_ELEITORES                          8809          5726      16041    8683
# QTD_ELEITORES_FEMININO                 4322          2871       8247    4287
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5741 entries, 0 to 5740
# Data columns (total 43 columns):
# NR_ANO_ELEICAO                     5741 non-null int64
# CD_PAIS                            5741 non-null int64
# NM_PAIS                            5741 non-null object
# SG_REGIAO                          5741 non-null object
# NM_REGIAO                          5741 non-null object
# SG_UF                              5741 non-null object
# NM_UF                              5741 non-null object
# CD_MUNICIPIO                       5741 non-null int64
# NM_MUNICIPIO                       5741 non-null object
# QTD_ELEITORES                      5741 non-null int64
# QTD_ELEITORES_FEMININO             5741 non-null int64
# QTD_ELEITORES_MASCULINO            5741 non-null int64
# QTD_ELEITORES_NAOINFORMADO         5741 non-null int64
# QTD_ELEITORES_MENOR16              5741 non-null int64
# QTD_ELEITORES_16                   5741 non-null int64
# ...

# %%
# 5 cidades com maior quantidade de eleitores deficientes
df.nlargest(5, 'QTD_ELEITORES_DEFICIENTE')
# Out:
#       NR_ANO_ELEICAO  CD_PAIS NM_PAIS SG_REGIAO NM_REGIAO SG_UF  \
# 5358            2018        1  Brasil        SE   Sudeste    SP
# 3660            2018        1  Brasil        SE   Sudeste    RJ
# 4990            2018        1  Brasil        SE   Sudeste    SP
# 535             2018        1  Brasil        NE  Nordeste    BA
# 4010            2018        1  Brasil         S       Sul    RS
#
#                   NM_UF  CD_MUNICIPIO    NM_MUNICIPIO  QTD_ELEITORES  ...  \
# 5358          São Paulo         71072       SÃO PAULO        9052724  ...
# 3660     Rio de Janeiro         60011  RIO DE JANEIRO        4891885  ...
# 4990          São Paulo         64777       GUARULHOS         814342  ...
# 535               Bahia         38490        SALVADOR        1827436  ...
# 4010  Rio Grande do Sul         85995   CAXIAS DO SUL         322901  ...
#
#       QTD_ELEITORES_90A94  QTD_ELEITORES_95A99  QTD_ELEITORES_MAIORIGUAL100  \
# ...

# %%
print('Eleitoras Femininas: ', df['QTD_ELEITORES_FEMININO'].sum())
print('Eleitores Masculinos: ',df['QTD_ELEITORES_MASCULINO'].sum())
# Out:
# Eleitoras Femininas:  77339897
# Eleitores Masculinos:  69902977

# %%
#variáveis para calculos de eleitores
tot_eleit = df['QTD_ELEITORES'].sum()
tot_fem = df['QTD_ELEITORES_FEMININO'].sum()
tot_mas = df['QTD_ELEITORES_MASCULINO'].sum()
tot_nao = df['QTD_ELEITORES_NAOINFORMADO'].sum()

# %%
# Valores Percentuais
print('Eleitores Femininos: ', ((tot_fem/tot_eleit) * 100).round(3), '%')
print('Eleitores Masculinos: ',((tot_mas/tot_eleit) * 100).round(3), '%')
print('Eleitores Masculinos: ',((tot_nao/tot_eleit) * 100).round(3), '%')
# Out:
# Eleitores Femininos:  52.503 %
# Eleitores Masculinos:  47.454 %
# Eleitores Masculinos:  0.043 %

# %%
# Total de municipios
df['NM_MUNICIPIO'].count()
# Out:
# 5741

# %%
# cidades com maior eleitores masculinos
df[df['QTD_ELEITORES_MASCULINO'] > df['QTD_ELEITORES_FEMININO']].count()
# Out:
# NR_ANO_ELEICAO                     2279
# CD_PAIS                            2279
# NM_PAIS                            2279
# SG_REGIAO                          2279
# NM_REGIAO                          2279
# SG_UF                              2279
# NM_UF                              2279
# CD_MUNICIPIO                       2279
# NM_MUNICIPIO                       2279
# QTD_ELEITORES                      2279
# QTD_ELEITORES_FEMININO             2279
# QTD_ELEITORES_MASCULINO            2279
# QTD_ELEITORES_NAOINFORMADO         2279
# QTD_ELEITORES_MENOR16              2279
# QTD_ELEITORES_16                   2279
# QTD_ELEITORES_17                   2279
# QTD_ELEITORES_18                   2279
# QTD_ELEITORES_19                   2279
# QTD_ELEITORES_20                   2279
# QTD_ELEITORES_21A24                2279
# QTD_ELEITORES_25A29                2279
# QTD_ELEITORES_30A34                2279
# QTD_ELEITORES_35A39                2279
# ...

# %%
df['RELACAO_FM'] = df['QTD_ELEITORES_FEMININO'] / df['QTD_ELEITORES_MASCULINO']
df['RELACAO_FM']
# Out:
# 0       0.963227
# 1       1.005604
# 2       1.058122
# 3       0.975205
# 4       0.947548
# 5       1.100727
# 6       1.097371
# 7       0.962963
# 8       0.856313
# 9       0.907075
# 10      0.875615
# 11      0.988480
# 12      1.019559
# 13      0.931376
# 14      0.891934
# 15      1.146723
# 16      0.957295
# 17      0.983254
# 18      0.974833
# 19      1.023063
# 20      0.954605
# 21      0.959773
# 22      1.114501
# 23      1.232397
# 24      1.061044
# 25      1.080232
# 26      1.072780
# 27      1.133742
# 28      1.034879
# 29      1.068133
#           ...
# 5711    1.172414
# 5712    1.014555
# 5713    1.241597
# 5714    1.119171
# 5715    1.432071
# 5716    1.118421
# 5717    1.661017
# 5718    1.000000
# 5719    0.230769
# 5720    1.054475
# 5721    1.090909
# 5722    1.250000
# 5723    2.266667
# 5724    1.057692
# 5725    1.232162
# 5726    1.144547
# 5727    6.000000
# 5728    1.647059
# 5729    0.839538
# 5730    1.666667
# 5731    1.343408
# ...

# %%
# municipios com maior relação f/m
df.nlargest(5, 'RELACAO_FM').T
# Out:
#                                      5581      5613      5652      5658  \
# NR_ANO_ELEICAO                       2018      2018      2018      2018
# CD_PAIS                                 2         2         2         2
# NM_PAIS                          Exterior  Exterior  Exterior  Exterior
# SG_REGIAO                               E         E         E         E
# NM_REGIAO                        Exterior  Exterior  Exterior  Exterior
# SG_UF                                  ZZ        ZZ        ZZ        ZZ
# NM_UF                            Exterior  Exterior  Exterior  Exterior
# CD_MUNICIPIO                        99350     38920     99422     29963
# NM_MUNICIPIO                       BAMAKO   COTONOU    LETHEM      LOMÉ
# QTD_ELEITORES                           1         2         1         3
# QTD_ELEITORES_FEMININO                  1         2         1         3
# QTD_ELEITORES_MASCULINO                 0         0         0         0
# ...

# %%
# Municipios com menor relação f/m
df.nsmallest(5, 'RELACAO_FM').T
# Out:
#                                         5592      5610      5625      5719  \
# NR_ANO_ELEICAO                          2018      2018      2018      2018
# CD_PAIS                                    2         2         2         2
# NM_PAIS                             Exterior  Exterior  Exterior  Exterior
# SG_REGIAO                                  E         E         E         E
# NM_REGIAO                           Exterior  Exterior  Exterior  Exterior
# SG_UF                                     ZZ        ZZ        ZZ        ZZ
# NM_UF                               Exterior  Exterior  Exterior  Exterior
# CD_MUNICIPIO                           39187     38903     99406     30546
# NM_MUNICIPIO                     BRAZZAVILLE   CONACRI  FREETOWN     SÓFIA
# QTD_ELEITORES                              3         2         2        16
# QTD_ELEITORES_FEMININO                     0         0         0         3
# ...

# %%
# criar dataframe para municipios do Brasil
df_brasil = df[df['CD_PAIS'] == 1].copy()
df_brasil.head(3).T
# Out:
#                                           0             1          2
# NR_ANO_ELEICAO                         2018          2018       2018
# CD_PAIS                                   1             1          1
# NM_PAIS                              Brasil        Brasil     Brasil
# SG_REGIAO                                 N             N          N
# NM_REGIAO                             Norte         Norte      Norte
# SG_UF                                    AC            AC         AC
# NM_UF                                  Acre          Acre       Acre
# CD_MUNICIPIO                           1120          1570       1058
# NM_MUNICIPIO                     ACRELÂNDIA  ASSIS BRASIL  BRASILÉIA
# QTD_ELEITORES                          8809          5726      16041
# QTD_ELEITORES_FEMININO                 4322          2871       8247
# QTD_ELEITORES_MASCULINO                4487          2855       7794
# QTD_ELEITORES_NAOINFORMADO                0             0          0
# ...

# %%
df_brasil.nlargest(5, 'RELACAO_FM').T
# Out:
#                                            3653      535         2894  \
# NR_ANO_ELEICAO                             2018      2018        2018
# CD_PAIS                                       1         1           1
# NM_PAIS                                  Brasil    Brasil      Brasil
# SG_REGIAO                                    SE        NE          NE
# NM_REGIAO                               Sudeste  Nordeste    Nordeste
# SG_UF                                        RJ        BA          PE
# NM_UF                            Rio de Janeiro     Bahia  Pernambuco
# CD_MUNICIPIO                              58122     38490       24910
# NM_MUNICIPIO                          QUEIMADOS  SALVADOR      OLINDA
# QTD_ELEITORES                             72971   1827436      276081
# QTD_ELEITORES_FEMININO                    41542   1022159      153719
# QTD_ELEITORES_MASCULINO                   31429    805276      122362
# ...

# %%
# municipios com mais homens
df_brasil.nsmallest(5, 'RELACAO_FM').T
# Out:
#                                                 2389            1237  \
# NR_ANO_ELEICAO                                  2018            2018
# CD_PAIS                                            1               1
# NM_PAIS                                       Brasil          Brasil
# SG_REGIAO                                         CO              NE
# NM_REGIAO                               Centro-Oeste        Nordeste
# SG_UF                                             MT              MA
# NM_UF                                    Mato Grosso        Maranhão
# CD_MUNICIPIO                                   90980            7900
# NM_MUNICIPIO                     SANTA CRUZ DO XINGU  MARAJÁ DO SENA
# QTD_ELEITORES                                   1571            6416
# QTD_ELEITORES_FEMININO                           676            2789
# QTD_ELEITORES_MASCULINO                          895            3625
# QTD_ELEITORES_NAOINFORMADO                         0               2
# ...

# %%
df_brasil[df_brasil['NM_MUNICIPIO'] == 'CASCAVEL'].T
# Out:
#                                      659       3261
# NR_ANO_ELEICAO                       2018      2018
# CD_PAIS                                 1         1
# NM_PAIS                            Brasil    Brasil
# SG_REGIAO                              NE         S
# NM_REGIAO                        Nordeste       Sul
# SG_UF                                  CE        PR
# NM_UF                               Ceará    Paraná
# CD_MUNICIPIO                        13692     74934
# NM_MUNICIPIO                     CASCAVEL  CASCAVEL
# QTD_ELEITORES                       51818    218448
# QTD_ELEITORES_FEMININO              27435    116464
# QTD_ELEITORES_MASCULINO             24383    101984
# QTD_ELEITORES_NAOINFORMADO              0         0
# QTD_ELEITORES_MENOR16                   0         0
# QTD_ELEITORES_16                      266       375
# QTD_ELEITORES_17                      747      1051
# QTD_ELEITORES_18                     1050      3312
# ...

# %%
# %matplotlib inline
df_brasil['RELACAO_FM'].plot.hist(bins=100, color='red')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# plotar a distribuição da relação F/M
sns.distplot(df_brasil['RELACAO_FM'], bins=100, color='red', kde=False)

# stilizando
plt.title('Relação Eleitoras/Eleitores', fontsize=18)
plt.xlabel('Eleitoras/Eleitores', fontsize=14)
plt.ylabel('Frequência', fontsize=14)
plt.axvline(1.0, color='black', linestyle='--')

# %%
# distribuição F/M por municipios
# por região do Brasil
sns.swarmplot(data=df_brasil, x='NM_REGIAO', y='RELACAO_FM')
plt.axhline(1.0, color='black', linestyle='--')

# %%
df_brasil.sort_values(by='RELACAO_FM', ascending=False).T

# %%
#plotar a quantidade total de eleitores por faixa etária
# gráfico de barras horizontal

# listar as colunas de interesse
lista = ['QTD_ELEITORES_16', 'QTD_ELEITORES_17', 'QTD_ELEITORES_18', 
         'QTD_ELEITORES_19', 'QTD_ELEITORES_20']
tot_idade = df[lista].sum()

# %%
#print
tot_idade.sort_values(ascending=False).plot.bar(rot=40)
